# %% [markdown]
# ## HW 3 Q1
# ##### Badri Narayanan Ramesh
# ##### bramesh@usc.edu
#
# ##### CSCI 699 Robot Learning (Fall 2025)
# ##### Prof. Erdem Biyik

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Answer to i

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Answer to ii

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Answer to iii

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Answer to iv

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Answer to v

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Answer to vi

# %% [markdown]
# ![alt text](image.png)

# %%
# Answer to vii

# %% [markdown]
# ![alt text](image-1.png)

# %%
# Answer to viii

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Answer to ix

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Answer to x
